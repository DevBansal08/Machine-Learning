# %%
import pandas as pd
import numpy as npy
import matplotlib.pyplot as plt
from sklearn import linear_model
df = pd.read_csv(r"D:\Random ML files\homeprices.csv")
print(df.head())
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area,df.price, color = "red", marker = "+")
plt.xlabel("Price(US$)")
plt.ylabel(" area")
# Out:
# Text(0, 0.5, ' area')

# %%
model = linear_model.LinearRegression()
model.fit(df[["area"]],df.price)
# Out:
# LinearRegression()

# %%
model.predict([[3300]])
# Out:
# D:\Machine_Learning\my_venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
d = pd.read_csv(r"D:\Random ML files\areas.csv")
print(d.head(3))
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p = model.predict(d)

# %%
d["prices"]= p
print(d)
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
d.to_csv("Prediction.csv", index= False)
